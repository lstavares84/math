# %% [markdown]
# ![Captura%20de%20tela%202023-02-07%20150107-2.jpg](attachment:Captura%20de%20tela%202023-02-07%20150107-2.jpg)

# %% [markdown]
# # MATH PUZZLE 01
#
# Add the numbers 1 to 6 on the intersections of the circles in order to the sum of the numbers of each of the 3 circles are the same.
# Replace i0, i1, i2, i3, i4 and i5 with 1, 2, 3, 4, 5 and 6.
# You can't repeat any number.

# %%
#Print permutations of 1 to 6 of a size 4
from itertools import permutations #import library to do permutations

size = 6

possibilities = list(permutations([1,2,3,4,5,6], size)) #Permutations of size 6

print(f'There are {len(possibilities)} possibilities to be analyzed\n')

print('The solutions are (i0, i1, i2, i3, i4, i5) = ')

solutions=0 #quantity of solutions found before start to calculate

for n in range(len(possibilities)):
    i=[]
    for j in range(size):
        i.append(possibilities[n][j])
        
    c1 = i[0]+i[2]+i[3]+i[4]
    c2 = i[0]+i[1]+i[3]+i[5]
    c3 = i[4]+i[1]+i[2]+i[5]
    if c1 == c2 and c1 == c3: #Test if the sums are the same
        sum = c1
        print(possibilities[n])
        solutions = solutions + 1
print(f'\n There are {solutions} possible solutions for this puzzle, where all the sum in the circle are equal to {sum}')
# Out:
# There are 720 possibilities to be analyzed
#
# The solutions are (i0, i1, i2, i3, i4, i5) =
# (1, 2, 3, 6, 4, 5)
# (1, 2, 4, 6, 3, 5)
# (1, 3, 2, 6, 5, 4)
# (1, 3, 5, 6, 2, 4)
# (1, 4, 2, 6, 5, 3)
# (1, 4, 5, 6, 2, 3)
# (1, 5, 3, 6, 4, 2)
# (1, 5, 4, 6, 3, 2)
# (2, 1, 3, 5, 4, 6)
# (2, 1, 4, 5, 3, 6)
# (2, 3, 1, 5, 6, 4)
# (2, 3, 6, 5, 1, 4)
# (2, 4, 1, 5, 6, 3)
# (2, 4, 6, 5, 1, 3)
# (2, 6, 3, 5, 4, 1)
# (2, 6, 4, 5, 3, 1)
# (3, 1, 2, 4, 5, 6)
# (3, 1, 5, 4, 2, 6)
# (3, 2, 1, 4, 6, 5)
# (3, 2, 6, 4, 1, 5)
# (3, 5, 1, 4, 6, 2)
# (3, 5, 6, 4, 1, 2)
# (3, 6, 2, 4, 5, 1)
# (3, 6, 5, 4, 2, 1)
# (4, 1, 2, 3, 5, 6)
# (4, 1, 5, 3, 2, 6)
# (4, 2, 1, 3, 6, 5)
# (4, 2, 6, 3, 1, 5)
# (4, 5, 1, 3, 6, 2)
# (4, 5, 6, 3, 1, 2)
# (4, 6, 2, 3, 5, 1)
# (4, 6, 5, 3, 2, 1)
# (5, 1, 3, 2, 4, 6)
# (5, 1, 4, 2, 3, 6)
# (5, 3, 1, 2, 6, 4)
# (5, 3, 6, 2, 1, 4)
# (5, 4, 1, 2, 6, 3)
# (5, 4, 6, 2, 1, 3)
# (5, 6, 3, 2, 4, 1)
# (5, 6, 4, 2, 3, 1)
# (6, 2, 3, 1, 4, 5)
# (6, 2, 4, 1, 3, 5)
# (6, 3, 2, 1, 5, 4)
# (6, 3, 5, 1, 2, 4)
# (6, 4, 2, 1, 5, 3)
# (6, 4, 5, 1, 2, 3)
# (6, 5, 3, 1, 4, 2)
# (6, 5, 4, 1, 3, 2)
#
#  There are 48 possible solutions for this puzzle, where all the sum in the circle are equal to 14
